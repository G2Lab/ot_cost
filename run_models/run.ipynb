# %%
ROOT_DIR = '/gpfs/commons/groups/gursoy_lab/aelhussein/ot_cost/otcost_fl_rebase'
import sys
sys.path.append(f'{ROOT_DIR}/code/helper')
import pipeline as pp
import models_helper as mh
import trainers as tr
import data_preprocessing as dp
import importlib
importlib.reload(pp)
importlib.reload(mh)
importlib.reload(tr)
importlib.reload(dp)
pass

# %%
costs_dict = {'Synthetic': [0.03, 0.10, 0.20, 0.30, 0.40, 0.50],
              'Credit': [0.12, 0.23, 0.30, 0.40],
              'Weather': [0.11, 0.19, 0.30, 0.40, 0.48],
              'EMNIST': [0.11, 0.19, 0.25, 0.34, 0.39],
              'CIFAR': [0.08, 0.21, 0.3, 0.38], 
              'IXITiny': [0.08, 0.28, 0.30],
              'ISIC': [0.06, 0.15, 0.19, 0.25, 0.3]
              }

# %% [markdown]
# # Synthetic

# %%
DATASET = 'Synthetic'
costs = costs_dict[DATASET]
results_scores, results_train_losses, results_val_losses, results_test_losses = pp.runAnalysis(DATASET, costs)
# Out:
# Stopping at epoch: 27
# Stopping at epoch: 58
# Stopping at epoch: 158
# Stopping at epoch: 102
# Stopping at epoch: 172
# Stopping at epoch: 29
# Stopping at epoch: 57
# Stopping at epoch: 156
# Stopping at epoch: 173
# Stopping at epoch: 170
# Stopping at epoch: 49
# Stopping at epoch: 47
# Stopping at epoch: 77
# Stopping at epoch: 172
# Stopping at epoch: 155
# Stopping at epoch: 43
# Stopping at epoch: 38
# Stopping at epoch: 40
# Stopping at epoch: 173
# Stopping at epoch: 160
# Stopping at epoch: 33
# Stopping at epoch: 61
# Stopping at epoch: 132
# Stopping at epoch: 180
# Stopping at epoch: 160
# Stopping at epoch: 31
# Stopping at epoch: 176
# Stopping at epoch: 163
# Stopping at epoch: 168
# Stopping at epoch: 160
# Stopping at epoch: 35
# Stopping at epoch: 56
# Stopping at epoch: 77
# Stopping at epoch: 166
# Stopping at epoch: 160
# Stopping at epoch: 35
# Stopping at epoch: 50
# Stopping at epoch: 102
# Stopping at epoch: 163
# Stopping at epoch: 154
# Stopping at epoch: 47
# Stopping at epoch: 71
# Stopping at epoch: 55
# Stopping at epoch: 32
# Stopping at epoch: 159
# Stopping at epoch: 51
# Stopping at epoch: 50
# Stopping at epoch: 174
# Stopping at epoch: 169
# Stopping at epoch: 157
# Stopping at epoch: 52
# Stopping at epoch: 42
# Stopping at epoch: 152
# Stopping at epoch: 43
# Stopping at epoch: 168
# Stopping at epoch: 59
# Stopping at epoch: 53
# Stopping at epoch: 170
# Stopping at epoch: 167
# Stopping at epoch: 157
# Stopping at epoch: 44
# Stopping at epoch: 33
# Stopping at epoch: 35
# Stopping at epoch: 180
# Stopping at epoch: 172
# Stopping at epoch: 31
# Stopping at epoch: 54
# Stopping at epoch: 35
# Stopping at epoch: 162
# Stopping at epoch: 175
# Stopping at epoch: 36
# Stopping at epoch: 44
# Stopping at epoch: 46
# Stopping at epoch: 68
# Stopping at epoch: 166
# Stopping at epoch: 157
# Stopping at epoch: 36
# Stopping at epoch: 58
# Stopping at epoch: 46
# Stopping at epoch: 57
# Stopping at epoch: 173
# Stopping at epoch: 42
# Stopping at epoch: 44
# Stopping at epoch: 56
# Stopping at epoch: 30
# Stopping at epoch: 170
# Stopping at epoch: 29
# Stopping at epoch: 53
# Stopping at epoch: 169
# Stopping at epoch: 167
# Stopping at epoch: 164
# Stopping at epoch: 35
# Stopping at epoch: 61
# Stopping at epoch: 37
# Stopping at epoch: 162
# Stopping at epoch: 181
# Stopping at epoch: 38
# Stopping at epoch: 44
# Stopping at epoch: 57
# Stopping at epoch: 161
# Stopping at epoch: 162
# Stopping at epoch: 52
# Stopping at epoch: 47
# Stopping at epoch: 71
# Stopping at epoch: 171
# Stopping at epoch: 163
# Stopping at epoch: 44
# Stopping at epoch: 70
# Stopping at epoch: 31
# Stopping at epoch: 170
# Stopping at epoch: 163
# Stopping at epoch: 38
# Stopping at epoch: 60
# Stopping at epoch: 166
# Stopping at epoch: 177
# Stopping at epoch: 163
# Stopping at epoch: 66
# Stopping at epoch: 59
# Stopping at epoch: 157
# Stopping at epoch: 165
# Stopping at epoch: 173
# Stopping at epoch: 34
# Stopping at epoch: 47
# Stopping at epoch: 163
# Stopping at epoch: 177
# Stopping at epoch: 165
# Stopping at epoch: 182
# Stopping at epoch: 81
# Stopping at epoch: 172
# Stopping at epoch: 71
# Stopping at epoch: 161
# Stopping at epoch: 30
# Stopping at epoch: 89
# Stopping at epoch: 173
# Stopping at epoch: 181
# Stopping at epoch: 161
# Stopping at epoch: 40
# Stopping at epoch: 41

# %% [markdown]
# # Credit

# %%
DATASET = 'Credit'
costs = costs_dict[DATASET]
results_scores, results_train_losses, results_val_losses, results_test_losses = pp.runAnalysis(DATASET, costs)

# %% [markdown]
# # Weather

# %%
DATASET = 'Weather'
costs = costs_dict[DATASET]
results_scores, results_train_losses, results_val_losses, results_test_losses = pp.runAnalysis(DATASET, costs)

# %% [markdown]
# # EMNIST

# %%
DATASET = 'EMNIST'
costs = costs_dict[DATASET]
results_scores, results_train_losses, results_val_losses, results_test_losses = pp.runAnalysis(DATASET, costs)

# %% [markdown]
# # CIFAR

# %%
DATASET = 'CIFAR'
costs = costs_dict[DATASET]
results_scores, results_train_losses, results_val_losses, results_test_losses = pp.runAnalysis(DATASET, costs)

# %% [markdown]
# # IXITiny

# %%
DATASET = 'IXITiny'
costs = costs_dict[DATASET]
results_scores, results_train_losses, results_val_losses, results_test_losses = pp.runAnalysis(DATASET, costs)

# %% [markdown]
# # ISIC

# %%
DATASET = 'ISIC'
costs = costs_dict[DATASET]
results_scores, results_train_losses, results_val_losses, results_test_losses = pp.runAnalysis(DATASET, costs)
